# %% [markdown]
# # Interés compuesto (GUI)
#
# Hacer una o ambas versiones del [ejercicio 13 del módulo 0 ](https://drive.google.com/open?id=1Dh6pdNxiMk10zRrcTDwbGi6rlHLGNVcL)sobre el cálculo del interés compuesto con una interfaz gráfica que actualice automáticamente el resultado a medida que el usuario introduce los datos
