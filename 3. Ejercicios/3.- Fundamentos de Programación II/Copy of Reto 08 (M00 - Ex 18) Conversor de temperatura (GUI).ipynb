# %% [markdown]
# # Calculadora IMC (GUI)
#
# Construir la [calculadora IMC](https://colab.research.google.com/drive/1eekZKAcM80tme2x28joRIelXXRW2SnW2#scrollTo=vlzy8Rp1EuwE&line=13&uniqifier=1) con todos los niveles con una interfaz de usuario gráfica y que se actualice según se cambian peso o altura. Introducir el peso y la altura con sliders. Las diferentes zonas deben estar indicadas en colores de modo que se vea donde se está.
