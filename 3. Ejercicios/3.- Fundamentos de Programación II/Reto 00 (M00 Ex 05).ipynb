# %% [markdown]
# # Operaciones matemáticas sencillas GUI
#
# Crear una GUI que introduciendo dos números nos devuelva su suma, resta, producto y división y que se actualice según se van introduciendo los números
