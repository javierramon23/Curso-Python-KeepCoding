# %% [markdown]
# # Contando Caracteres (II)
#
# Implementar el [ejercicio 2 del módulo 00](https://colab.research.google.com/drive/1jLDOM-UuM-nFDbJ8HwfItpGQrnZWsgOH#scrollTo=ctTIMAXdkRrK) pero utilizando un interfaz gráfico de usuario (GUI) de forma que el contador se actualice a medida que el usuario teclea un carácter.
