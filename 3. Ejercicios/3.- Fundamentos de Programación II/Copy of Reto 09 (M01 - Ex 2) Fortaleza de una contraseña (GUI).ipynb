# %% [markdown]
# # Fortaleza de una contraseña (GUI)
#
# Hacer el mismo ejercicio que en el [segundo del módulo 01](https://colab.research.google.com/drive/1UZFZUscxBwDY3MmAI36WIo_ejLDf1YZx#scrollTo=iizIGm5oMoDz&line=13&uniqifier=1) de manera que devuelva gráficamente y con actualización inmediata a medida que se introduce la contraseña su fortalez.
