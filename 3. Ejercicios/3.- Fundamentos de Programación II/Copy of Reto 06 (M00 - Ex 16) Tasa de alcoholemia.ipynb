# %% [markdown]
# # Calculadora de alcoholemia
#
# Repetir el [ejercicio 16 del módulo 0](https://drive.google.com/open?id=1d2kAZ9zLC8bGI9rp0dYhsOze6jfF8iYE) creando una web que permita añadir o quitar bebidas fácilmente y que calcule la alcoholemia de forma inmediata según se introducen las bebidas
