# %% [markdown]
# # Superficie de una habitación (GUI)
#
# Crear una versión del cálculo de la superficie de una habitación en yardas o metros cuadrados con interfaz gráfica que se actualice según cambian las entradas
