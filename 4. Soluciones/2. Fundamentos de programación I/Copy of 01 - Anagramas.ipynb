# %% [markdown]
# # Anagramas
#
# Crear un programa que indique si una cadena es un anagrama de otra (mismos carácteres en orden diferente). Ejemplo
#
# ```
# Primera cadena: otra
# Segunda cadena: rota
#
# "otra" y "rota" son anagramas
# ```
#
# ## Restricciones
#
# 1. Hacerlo con la función `esAnagrama`
# 2. Ambas palabras deben tener la misma longitud

# %%
def isAnagram(c1, c2):
  if len(c1) != len(c2):
    return False 

  lc2 = list(c2)
  for i in range(0, len(c1)):
    print(lc2)
    for j in range(0, len(c2)):
      if c1[i] == lc2[j]:
        lc2[j] = '*'
        break
  
  print(lc2)
        
  comp = '*'*len(c2)
  c2 = "".join(lc2)
  print(comp, 'vs', c2)
  return comp == c2

def isAnagramI(c1, c2):
  if len(c1) != len(c2):
    return False 
  
  posi = []

  for i in range(0, len(c1)):  
    print(posi)
    for j in range(0, len(c2)):
      if c1[i] == c2[j] and j not in posi:
        posi.append(j)
  
  print(posi)
  return len(posi) == len(c2)

# %% [markdown]
# ##Notas a la solución propuesta
#
# En la línea 5 se crea una lista con los caracteres de la cadena c2. Esto se hace necesario ya que Python define los strings como inmutables y el intento de modificar directamente un caracter de una cadena genera la excepción `'str' object does not support item assignment`. Una forma de solucionarlo es la transformaciónn de string (tupla de caracteres) en una lista de caracteres

# %% [markdown]
# ## Reto
#
# 1. Hacerlo sin las facilidades de manejo de cadenas de python

# %%
isAnagram('rota', 'otra')
# Out:
# ['o', 't', 'r', 'a']
# ['o', 't', '*', 'a']
# ['*', 't', '*', 'a']
# ['*', '*', '*', 'a']
# ['*', '*', '*', '*']
# **** vs ****
# True
