# %% [markdown]
# # Conversor de temperaturas con funciones
#
# Realizar el conversor del [ejercicio 17 del módulo 0](https://colab.research.google.com/drive/15gkQPxEclDSculW_POh0sxzD9z4cfulo#scrollTo=yHx0iun1Xz_l&line=13&uniqifier=1) con funciones
