# %% [markdown]
# # Encriptando contraseñas
#
# Hacer el mismo programa que el [ejercicio 15 del módulo 0](https://drive.google.com/open?id=1ntMgeD7NCNzUMUxKg0hpLa5wurkS4eYZ) utilizando un diccionario y encriptando la contraseña con [bcrypt](https://pypi.org/project/bcrypt/)
